# %%
#1.     Write a program to print Hello World

print("Hello! world")
# Out:
# Hello! world

# %%
# 2.	Write a program to take input of your name and surname and print it

name= input("enter your name")
surname = input("enter you surname")
# Out:
# enter your name chanchal
# enter you surname sharma

# %%
print(name,surname)
# Out:
# chanchal sharma

# %%
# 3.    Write a program to print the following content at the center of screen without any inbuilt functions.

print(" i am a programmer")
# Out:
#  i am a programmer

# %%
# 4.	Write a Python program that displays your name, age, and address on three different lines.

Name = "Chanchal"; Address= "Mansarovar Jaipur"; Age=27;

print(Name)
print(Address)
print(Age)
# Out:
# Chanchal
# Mansarovar Jaipur
# 27

# %%
# 5.	Write a program to show list of keywords and check its length

import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(len(keyword.kwlist))
# Out:
# 35

# %%
import keyword
print(keyword.__doc__)
# Out:
# Keywords (from "Grammar/python.gram")
#
# This file is automatically generated; please don't muck it up!
#
# To update the symbols in this file, 'cd' to the top directory of
# the python source tree and run:
#
#     PYTHONPATH=Tools/peg_generator python3 -m pegen.keywordgen         Grammar/python.gram         Grammar/Tokens         Lib/keyword.py
#
# Alternatively, you can run 'make regen-keyword'.

# %%
#7.	Write a program to view doc string using short cut method and print only a doc string from below code

def fun (num1, num2):
    """This is a general function for performing numerous functions on two numbers."""
    pass

print(fun.__doc__)

N= fun(5,6)
# Out:
# This is a general function for performing numerous functions on two numbers.

# %%
print(num1+num2)
print(num2-num1)
# Out:
# 11
# 1

# %%
#8.	Write a Python program to swap two variables without using third variable or any loops.
salary = 500
Expenses= 300

salary, Expenses = Expenses, salary

print("salary",salary)
print("Expenses",Expenses)
# Out:
# salary 300
# Expenses 500

# %%
# 9.	Write a program to find the length of the name entered by user.

Name = input("enter your name")

print(len(Name))
# Out:
# enter your name rahul
# 5

# %%
#10.	Write a program to print the following
name = "chanchal"
border = "*" * (len(name) + 4)

print(border)
print(f"* {name} *")
print(border)
# Out:
# ************
# * chanchal *
# ************
